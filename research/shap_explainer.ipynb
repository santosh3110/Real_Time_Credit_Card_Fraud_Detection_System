# %%
import shap
import pickle
import streamlit.components.v1 as components
import matplotlib.pyplot as plt
import os

# %%
# %pwd
# Out:
# '/home/santoshkumarguntupalli/data_science/Real_Time_Credit_Card_Fraud_Detection_System/research'

# %%
os.chdir("../")
# %pwd
# Out:
# '/home/santoshkumarguntupalli/data_science/Real_Time_Credit_Card_Fraud_Detection_System'

# %%
# Load SHAP values
with open("artifacts/reports/evaluation/reports/shap/shap_values.pkl", "rb") as f:
    shap_values = pickle.load(f)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.waterfall(shap_values[7])
